# %% [markdown]
# # 입출력

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
a=2
b=3.14
print("%d %f" %(a,b))
# Out:
# 2 3.140000

# %%
x=input() # string
# Out:
# 30

# %%
b=float(input()) # number
# Out:
# 3

# %% [markdown]
# # 파일 입출력

# %%
f=open("a.txt",'w')
for i in range(5):
    f.write("%d\n" %(i))
f.close()

# %%
f=open("a.txt",'r')
for i in f:
    print(i)
f.close
# Out:
# 0
#
# 1
#
# 2
#
# 3
#
# 4
# <function TextIOWrapper.close()>

# %%
f=open("a.txt",'r')
a=f.readlines()
f.close()
a
# Out:
# ['0\n', '1\n', '2\n', '3\n', '4\n']

# %%
# loadtxt is useful
import numpy as np
a=np.loadtxt("a.txt",float)
a
# Out:
# array([0., 1., 2., 3., 4.])
